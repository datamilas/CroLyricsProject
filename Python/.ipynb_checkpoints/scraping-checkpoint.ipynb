# %%
import pandas as pd
import base64
import os

from requests import get
from bs4 import BeautifulSoup
from time import sleep
## Create empty df:
# column_names = ["Artist", "Song", "Song_ID", "Lyrics", "Url"]
# df = pd.DataFrame(columns = column_names)

##OR##

## Load existing data and add to it:
#pd.read_csv('data.csv')

# %%
# Scraping cuspajz.com for song lyrics by artist (change url to change artist)

# Based on:
#    https://www.dataquest.io/blog/web-scraping-beautifulsoup/
#    https://github.com/aakashbansal/Songs-Lyrics-Web-Scraper/blob/master/Lyrics%20Scraper.ipynb

artist = 'Mate Miso Kovac'
# artist url
url = 'https://cuspajz.com/tekstovi-pjesama/izvodjac/mate-miso-kovac.html'

# generate random artist ID and make sure it doesnt have '_'
artist_ID = base64.b64encode(os.urandom(6)).decode('ascii')
while(artist_ID.find('_')>=0):
    artist_ID = base64.b64encode(os.urandom(6)).decode('ascii')
    
delay = 2

response = get(url)
# print(response.text[:500])
html_soup = BeautifulSoup(response.text, 'html.parser')
# print(type(html_soup))


# Get the list of songs
songs = html_soup.find_all('ul', class_='songList')

# %%
    for col_index, column in enumerate(songs):
        songs = column.find_all('li')

        for index, song in enumerate(songs):

            song_name = song.a.text
            song_url = song.a['href']

            url = 'https://cuspajz.com/'+song_url

            response = get(url)

            html_soup = BeautifulSoup(response.text, 'html.parser')

            song_lyrics = html_soup.find_all('p', class_='clearfix')
            lyrics =  song_lyrics[0].get_text()
            
            song_ID = artist_ID + '_' + str(1) + '_' + str(index)  

            new_entry = pd.DataFrame([[artist, song_name, song_ID, lyrics, url]], columns=["Artist", "Song", "Song_ID", "Lyrics", "Url"])
            df = df.append(new_entry, ignore_index=True)


#             file.write("###"+song_name+"###")
#             file.write("\n\n")
#             file.write(lyrics)
#             file.write("\n\n")

            print("Lyrics successfully written to file for : " + song_name)
                      
            sleep(delay)
# Out:
# Lyrics successfully written to file for : A kad se tebi opet vratim
# Lyrics successfully written to file for : Ako me ostaviš
# Lyrics successfully written to file for : Ako si pošla spat
# Lyrics successfully written to file for : Ako srce mira nema
# Lyrics successfully written to file for : Balada o vremenu
# Lyrics successfully written to file for : Bez rastanka suza nema
# Lyrics successfully written to file for : Bijela lađa
# Lyrics successfully written to file for : Bili, bili
# Lyrics successfully written to file for : Bog mi daje, Bog mi uzima
# Lyrics successfully written to file for : Budi čovjek dobre volje
# Lyrics successfully written to file for : Croatia victoria (duet Josip Katalenić)
# Lyrics successfully written to file for : Čovjek bez adrese
# Lyrics successfully written to file for : Da li je to ljubav prava
# Lyrics successfully written to file for : Da te nisam volio
# Lyrics successfully written to file for : Dalmacija u mom oku
# Lyrics successfully written to file for : Dalmaciju dišem misto zraka
# Lyrics successfully written to file for : Dalmatino
# Lyrics successfully written to file for : Dalmatinske lipe oči
# Lyrics successfully written to file for : Dobra ti večer, mati moja
# Lyrics successfully written to file for : Drugi joj raspliće kosu, a ja je volim
# Lyrics successfully written to file for : Eviva l'amor
# Lyrics successfully written to file for : Gdje su sada one noći
# Lyrics successfully written to file for : Grobovi im nikad oprostiti neće
# Lyrics successfully written to file for : Hej, živote, što me snađe
# Lyrics successfully written to file for : I dođe dan
# Lyrics successfully written to file for : Idemo dalje pjesmo moja
# Lyrics successfully written to file for : Imoćani čuvaju Hrvate
# Lyrics successfully written to file for : Iz tvojih rana izrasti će cvijeće
# Lyrics successfully written to file for : Izgubljena ljubav
# Lyrics successfully written to file for : Ja ne mogu drugo nego da je volim
# Lyrics successfully written to file for : Ja nikog nemam
# Lyrics successfully written to file for : Ja sam kovač svoje sreće
# Lyrics successfully written to file for : Jedan dan života
# Lyrics successfully written to file for : Jemala sam dragoga
# Lyrics successfully written to file for : Još se držim, još se ne dam
# Lyrics successfully written to file for : Kad čuješ pjesmu o svom rodnom kraju
# Lyrics successfully written to file for : Kad jednom odeš, ne vraćaj se više
# Lyrics successfully written to file for : Kad plačeš i kad se smiješ
# Lyrics successfully written to file for : Kap od mora
# Lyrics successfully written to file for : Košulja od zlata
# Lyrics successfully written to file for : Kralju nebeski
# Lyrics successfully written to file for : Laka ti noć
# Lyrics successfully written to file for : Marija
# Lyrics successfully written to file for : Mi smo se voljeli
# Lyrics successfully written to file for : Moja Kristina
# Lyrics successfully written to file for : Moram li da umrem
# Lyrics successfully written to file for : Možda smo se mogli zagrliti jače
# Lyrics successfully written to file for : Najljepše su oči moje majke
# Lyrics successfully written to file for : Ne mogu da te zaboravim
# Lyrics successfully written to file for : Ne reci kuda ideš
# Lyrics successfully written to file for : Ne traži da ti budem prijatelj
# Lyrics successfully written to file for : Nebu puštam bijelu pticu
# Lyrics successfully written to file for : Nek teku sve vode
# Lyrics successfully written to file for : Neka stane život cijeli
# Lyrics successfully written to file for : Ni'ko ne zna kako mi je
# Lyrics successfully written to file for : Nije vrijeme da se rastanemo
# Lyrics successfully written to file for : Nisam ja varošanka
# Lyrics successfully written to file for : Noćas ćemo zemlji ko materi reći
# Lyrics successfully written to file for : Obala mojih snova
# Lyrics successfully written to file for : Od kavane do kavane
# Lyrics successfully written to file for : Odlaze sanjari
# Lyrics successfully written to file for : Odvest ću te na vjenčanje
# Lyrics successfully written to file for : Oprosti, ne mogu doći
# Lyrics successfully written to file for : Ostala si uvijek ista
# Lyrics successfully written to file for : Otvori srce
# Lyrics successfully written to file for : Ovo je naša noć
# Lyrics successfully written to file for : Pjeni se more
# Lyrics successfully written to file for : Plesala je samo jedno ljeto
# Lyrics successfully written to file for : Ponoćna serenada
# Lyrics successfully written to file for : Ponovo me voli
# Lyrics successfully written to file for : Posljednje kiše
# Lyrics successfully written to file for : Pozdravi mi ženu plave kose
# Lyrics successfully written to file for : Propinju se dušom jedra
# Lyrics successfully written to file for : Ranjeno je srce moje
# Lyrics successfully written to file for : Romantika
# Lyrics successfully written to file for : Sad živim sam
# Lyrics successfully written to file for : Samo nas nebo rastavit može
# Lyrics successfully written to file for : Sićaš li se Splita grada
# Lyrics successfully written to file for : Slušaj, majko, moju pjesmu
# Lyrics successfully written to file for : Suza nebeska
# Lyrics successfully written to file for : Sve što traje
# Lyrics successfully written to file for : Svirajte mi marijači
# Lyrics successfully written to file for : Šibenske kale
# Lyrics successfully written to file for : Što nas tako veže
# Lyrics successfully written to file for : Ti gitaro samo sviraj
# Lyrics successfully written to file for : Ti si pjesma moje duše
# Lyrics successfully written to file for : Tiha noć
# Lyrics successfully written to file for : Tri suze
# Lyrics successfully written to file for : Tvoje lice
# Lyrics successfully written to file for : Uvijek ima nešto dalje
# Lyrics successfully written to file for : Više od života ne mogu ti dati
# Lyrics successfully written to file for : Volim te i danas kao nekad
# Lyrics successfully written to file for : Vraćam ti se, Dalmacijo, mati
# Lyrics successfully written to file for : Vrijeme plakanja
# Lyrics successfully written to file for : Za mene sreće nema
# Lyrics successfully written to file for : Zajedno smo
# Lyrics successfully written to file for : Zapisi jeseni
# Lyrics successfully written to file for : Zašto
# Lyrics successfully written to file for : Zbogom nevjerna dušo
# Lyrics successfully written to file for : Zelena trava doma mog
# Lyrics successfully written to file for : Znali su svi
# Lyrics successfully written to file for : Željeli su da me sruše
# Lyrics successfully written to file for : Živim danas, ne mislim na sutra
# Lyrics successfully written to file for : Adios amor
# Lyrics successfully written to file for : Ako sam ikad ljubav dao
# Lyrics successfully written to file for : Ako spavaš vilo moja
# Lyrics successfully written to file for : Ako tvoja duša moju pjesmu sluša
# Lyrics successfully written to file for : Balada o zelenim očima
# Lyrics successfully written to file for : Bez tebe ja polako umirem
# Lyrics successfully written to file for : Bila je kao pjesma
# Lyrics successfully written to file for : Bit ću daleko
# Lyrics successfully written to file for : Brod bez luke
# Lyrics successfully written to file for : Budi jaka
# Lyrics successfully written to file for : Čemu da živim
# Lyrics successfully written to file for : Čuvajte mi pismu
# Lyrics successfully written to file for : Da te nema
# Lyrics successfully written to file for : Da te sretnem za sto godina
# Lyrics successfully written to file for : Dalmacijo, sveto ime
# Lyrics successfully written to file for : Dalmatinac
# Lyrics successfully written to file for : Dalmatinska
# Lyrics successfully written to file for : Digao sam ruke od života
# Lyrics successfully written to file for : Dome moj
# Lyrics successfully written to file for : Dušu sam dao
# Lyrics successfully written to file for : Gdje ste noćas prijatelji
# Lyrics successfully written to file for : Gitaro moja, jedini druže
# Lyrics successfully written to file for : Hajde živote prijatelj mi budi
# Lyrics successfully written to file for : Hrvatska ljubavi
# Lyrics successfully written to file for : I na križu
# Lyrics successfully written to file for : Igramo zadnji tango
# Lyrics successfully written to file for : Ivana
# Lyrics successfully written to file for : Izajdi na prozor (Klapa Šibenik)
# Lyrics successfully written to file for : Ja bez tebe sreće nemam
# Lyrics successfully written to file for : Ja nemam više razloga da živim
# Lyrics successfully written to file for : Ja odlazim (Ya me voi)
# Lyrics successfully written to file for : Ja želim mir
# Lyrics successfully written to file for : Jedina prava
# Lyrics successfully written to file for : Još i danas teku suze jedne žene
# Lyrics successfully written to file for : Južnjačke sam krvi
# Lyrics successfully written to file for : Kad dođem blizu Hvara
# Lyrics successfully written to file for : Kad pjevam suze teku
# Lyrics successfully written to file for : Kako mi je dobro znaju
# Lyrics successfully written to file for : Kaži mi kaži
# Lyrics successfully written to file for : Kralj tuge
# Lyrics successfully written to file for : La Paloma
# Lyrics successfully written to file for : Malo mi je jedan život
# Lyrics successfully written to file for : Meni treba tvoja ljubav
# Lyrics successfully written to file for : Mogli smo više
# Lyrics successfully written to file for : Molitva za domovinu
# Lyrics successfully written to file for : Mornaru sretan put
# Lyrics successfully written to file for : Na križu
# Lyrics successfully written to file for : Ne idi, ne idi
# Lyrics successfully written to file for : Ne mogu prestati da te volim (I can't stop loving you)
# Lyrics successfully written to file for : Ne sudi mi
# Lyrics successfully written to file for : Ne traži drugu ljubav
# Lyrics successfully written to file for : Neću da te kunem
# Lyrics successfully written to file for : Nek teku vode sve
# Lyrics successfully written to file for : Nema smijeha na tvom licu
# Lyrics successfully written to file for : Nije lako biti sam
# Lyrics successfully written to file for : Nikoga nisam volio tako
# Lyrics successfully written to file for : Noć ti dira crne kose
# Lyrics successfully written to file for : Noćas sam te sanjao
# Lyrics successfully written to file for : Oči tvoje plave
# Lyrics successfully written to file for : Odavno više ne plačem zbog tebe
# Lyrics successfully written to file for : Odrasli smo
# Lyrics successfully written to file for : Oj ti dušo duše moje
# Lyrics successfully written to file for : Ostala je samo jedna pjesma
# Lyrics successfully written to file for : Ostavi me, živote
# Lyrics successfully written to file for : Ove noći svi su sretni
# Lyrics successfully written to file for : Pamtit ću te (za sva vremena)
# Lyrics successfully written to file for : Pjevaj legendo
# Lyrics successfully written to file for : Poljubi zemlju
# Lyrics successfully written to file for : Ponoćni blues
# Lyrics successfully written to file for : Poslije toliko godina
# Lyrics successfully written to file for : Potraži me u pjesmi
# Lyrics successfully written to file for : Prokleto je jutro sutrašnje
# Lyrics successfully written to file for : Proplakat će zora
# Lyrics successfully written to file for : Reci zbogom
# Lyrics successfully written to file for : Rođen sam da volim
# Lyrics successfully written to file for : Samo jednom ljubav
# Lyrics successfully written to file for : Serenada
# Lyrics successfully written to file for : Sinoć kad sam ti proša
# Lyrics successfully written to file for : Sutra mi sude
# Lyrics successfully written to file for : Sve što mi život pruža
# Lyrics successfully written to file for : Svi pjevaju, ja ne čujem
# Lyrics successfully written to file for : Šibenska balada
# Lyrics successfully written to file for : Što je to u meni prokleto
# Lyrics successfully written to file for : Šuti srce, mogli bi te čuti
# Lyrics successfully written to file for : Ti mi budi vjerna
# Lyrics successfully written to file for : Ti si pjesma moje duše (alter)
# Lyrics successfully written to file for : To se zove ljubav
# Lyrics successfully written to file for : Tužno srce moje
# Lyrics successfully written to file for : U svakoj te ženi pokušavam naći
# Lyrics successfully written to file for : Varljivo ljeto
# Lyrics successfully written to file for : Više se nećeš vratiti
# Lyrics successfully written to file for : Volim te za sva vrimena
# Lyrics successfully written to file for : Vrelo mog života
# Lyrics successfully written to file for : Za kim zvono plače
# Lyrics successfully written to file for : Za tvoju ljubav sve bih dao
# Lyrics successfully written to file for : Zalij to cvijeće suzama sreće
# Lyrics successfully written to file for : Zaplešimo stara
# Lyrics successfully written to file for : Zbog tebe, ljubavi moja
# Lyrics successfully written to file for : Zbogom zvijezdo
# Lyrics successfully written to file for : Zeleno, zeleno
# Lyrics successfully written to file for : Znam da si sama
# Lyrics successfully written to file for : Žena s juga

# %%
df.to_csv('data.csv', index=False)

# %%
# Out:
# 'Zwn2Yv0K_1_101'

# %%
df[0:45]
# Out:
#          Artist                                 Song      Song_ID  \
# 0   Novi fosili                     Ako se rastanemo   oOIOCzZV_0
# 1   Novi fosili                  Bilo mi je prvi put   oOIOCzZV_1
# 2   Novi fosili          Čuješ li me, je l' ti drago   oOIOCzZV_2
# 3   Novi fosili                         Dijete sreće   oOIOCzZV_3
# 4   Novi fosili                        Djeca ljubavi   oOIOCzZV_4
# 5   Novi fosili                       Dobre djevojke   oOIOCzZV_5
# 6   Novi fosili            E da si barem noćas ovdje   oOIOCzZV_6
# 7   Novi fosili                        Hoću li znati   oOIOCzZV_7
# 8   Novi fosili                       Ja sam za ples   oOIOCzZV_8
# 9   Novi fosili                           Jedna suza   oOIOCzZV_9
# 10  Novi fosili                             Joj, joj  oOIOCzZV_10
# 11  Novi fosili                   Kad budemo ja i ti  oOIOCzZV_11
# 12  Novi fosili                   Kad naš brod plovi  oOIOCzZV_12
# 13  Novi fosili               Ključ je ispod otirača  oOIOCzZV_13
# 14  Novi fosili                       Kuca srce moje  oOIOCzZV_14
# 15  Novi fosili               Ljubav koja nema kraja  oOIOCzZV_15
# 16  Novi fosili                            Mali Ćiro  oOIOCzZV_16
# 17  Novi fosili                                Mario  oOIOCzZV_17
# 18  Novi fosili                                 Mimi  oOIOCzZV_18
# 19  Novi fosili                        Najdraže moje  oOIOCzZV_19
# 20  Novi fosili                          Ne plaši se  oOIOCzZV_20
# 21  Novi fosili      Neka vali gingolaju svoje barke  oOIOCzZV_21
# 22  Novi fosili                          Neveni žuti  oOIOCzZV_22
# 23  Novi fosili                Nikad više staro vino  oOIOCzZV_23
# 24  Novi fosili            Noćas umiru stare ljubavi  oOIOCzZV_24
# 25  Novi fosili               Obriši suze generacijo  oOIOCzZV_25
# 26  Novi fosili                   Pazi da ne nazebeš  oOIOCzZV_26
# 27  Novi fosili                        Poslije svega  oOIOCzZV_27
# 28  Novi fosili                  Radije budi mi brat  oOIOCzZV_28
# 29  Novi fosili                   Reci mi tiho, tiho  oOIOCzZV_29
# 30  Novi fosili                      Samo mi se javi  oOIOCzZV_30
# 31  Novi fosili                            Sanjaj me  oOIOCzZV_31
# 32  Novi fosili                            Simpatija  oOIOCzZV_32
# 33  Novi fosili                           Sklopi oči  oOIOCzZV_33
# 34  Novi fosili                                Šu šu  oOIOCzZV_34
# 35  Novi fosili             Tako je malo riječi palo  oOIOCzZV_35
# 36  Novi fosili                                Tonka  oOIOCzZV_36
# 37  Novi fosili                     Tvoje plave kose  oOIOCzZV_37
# 38  Novi fosili                              Vrijeme  oOIOCzZV_38
# 39  Novi fosili                     Za domovinu našu  oOIOCzZV_39
# 40  Novi fosili                               Zbogom  oOIOCzZV_40
# 41  Novi fosili                             Zovem te  oOIOCzZV_41
# 42  Novi fosili                    Bilo je prelijepo   oOIOCzZV_0
# 43  Novi fosili  Budi uvijek blizu (kao što si sada)   oOIOCzZV_1
# 44  Novi fosili                       Da te ne volim   oOIOCzZV_2
#
#                                                Lyrics  \
# 0   ne govorim s tobom,\r\ni ništa nije kao prije,...
# 1   Bilo je nebo na tvome čelu\r\nU srcu zdjela vr...
# 2
# 3   ja sam dijete srece\r\ni nepostojim\r\nne voli...
# 4   Prvi put ti kazem da, da se bojim svitanja\r\n...
# 5   Budi dobra ti, nemoj gradom lutati\r\nmini ne ...
# 6   Obuci cu nocas haljinu sto volis\r\nDignuti ko...
# 7   Hoću li znati, hoću li\r\nTvoju ljubav zauvjek...
# 8   I wanna dance! O ho...\r\nJa sam za ples! O je...
# 9   Jedna suza, jedna suza\n\r\nHej vlakovi zorom ...
# 10  Čići se i Peri\r\nRodi tako sinčić drag\r\nNis...
# 11  Ako ti dozvolim\r\nda me sad poljubis\r\nnesto...
# 12  Kad naš brod plovi plovi i ribu lovi\r\nNa jar...
# 13  U pocetku sve je tako sjajno\r\nTraje ljubav j...
# 14
# 15  Sve na svijetu dao bih ti ja\r\nsvog zivota de...
# 16  U neboderu jednom\r\nU prizemlju dolje\r\nZivi...
# 17  Mozda bi opet mogli mi\r\nbilo bi bolje sada\r...
# 18  Noc je hladna i nije vazan grad\r\nTko zna s k...
# 19  Ako te izgubim, najdraže moje\r\nUtopit će se ...
# 20  Tako zelim da ti pjevam pjesmu\r\nposve tiho, ...
# 21  Upeklo je ludo sunce\r\nsvaku dracu, svaku val...
# 22  Niz prozore vecer kaplje\r\nCekam te i ove noc...
# 23  Jos je uvijek sunce blago\r\njos su uvijek noc...
# 24  Ako ti kazem\r\nDa te volim jos\r\nHoce li and...
# 25
# 26  Idi sad\r\nPonesi sve sto zazelis\r\nIdi sad\r...
# 27  Prijatelji dolaze na vrijeme\r\nI vec su upalj...
# 28  Ponovo te vidam\r\nUvijek ides sam\r\nTvoj sne...
# 29  Kada more susti, kada zvijezde gore\r\nkada ze...
# 30  Ugasili smo davno\r\nPetrolejke i luci\r\nI po...
# 31  Ugasnut će jednom ljubav naša\r\nnegdje drugdj...
# 32  Kad ovu noć okreneš zadnji list\r\ni tiho već ...
# 33  Sklopi oci kad zazelis da me vidis\r\njer ako ...
# 34  Šu, šu, svi već šuškaju o tom\r\nšu, šu, da me...
# 35  Tako je malo rijeci palo\r\nal' nije mi stalo,...
# 36  Jedno pored drugog disemo u tami\r\nA jesmo li...
# 37  Cinilo se da svemu je kraj\r\nSjecati se niceg...
# 38  Vrijeme zivot nam daje\r\nDaje i uzima\r\nVrij...
# 39  Za domovimu nasu\r\nZlacana zora rudi\r\nZa do...
# 40  Sad' kad' voliš njenu kosu\r\ni kad' ljubiš oč...
# 41  Subotom svadbe dolaze\r\ndjevojke u bjelom pro...
# 42  Hladne mokre ulice\r\nsvaki korak sakriju\r\ng...
# 43  Kad se prsti spuste na umorne žice\r\nI poslje...
# 44  Da te ne volim\r\nBilo bi mi lako, bilo bi mi ...
#
#                                                   Url
# 0   https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 1   https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 2   https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 3   https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 4   https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 5   https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 6   https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 7   https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 8   https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 9   https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 10  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 11  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 12  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 13  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 14  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 15  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 16  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 17  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 18  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 19  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 20  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 21  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 22  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 23  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 24  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 25  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 26  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 27  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 28  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 29  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 30  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 31  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 32  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 33  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 34  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 35  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 36  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 37  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 38  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 39  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 40  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 41  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 42  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 43  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
# 44  https://cuspajz.com//tekstovi-pjesama/pjesma/n...
