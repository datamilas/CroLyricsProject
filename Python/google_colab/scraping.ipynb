# %%
# !pip install selenium
# !pip install discogs_client
# !pip install unidecode

# !pip install selenium
# !apt-get update # to update ubuntu to correctly run apt install
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
import sys
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')
# Out:
# Collecting selenium
#   Downloading selenium-4.1.2-py3-none-any.whl (963 kB)
#      |████████████████████████████████| 963 kB 5.1 MB/s
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting urllib3[secure,socks]~=1.26
#   Downloading urllib3-1.26.8-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 63.1 MB/s
# Collecting trio~=0.17
#   Downloading trio-0.20.0-py3-none-any.whl (359 kB)
#      |████████████████████████████████| 359 kB 67.4 MB/s
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.10)
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting outcome
#   Downloading outcome-1.1.0-py2.py3-none-any.whl (9.7 kB)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.1.0-py3-none-any.whl (24 kB)
# Collecting pyOpenSSL>=0.14
#   Downloading pyOpenSSL-22.0.0-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 4.2 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Collecting cryptography>=1.3.4
#   Downloading cryptography-36.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 42.3 MB/s
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium) (2.21)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 4.7 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from h11<1,>=0.9.0->wsproto>=0.14->trio-websocket~=0.9->selenium) (3.10.0.2)
# Installing collected packages: sniffio, outcome, h11, cryptography, async-generator, wsproto, urllib3, trio, pyOpenSSL, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.8 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed async-generator-1.10 cryptography-36.0.1 h11-0.13.0 outcome-1.1.0 pyOpenSSL-22.0.0 selenium-4.1.2 sniffio-1.2.0 trio-0.20.0 trio-websocket-0.9.2 urllib3-1.26.8 wsproto-1.1.0
# Collecting discogs_client
#   Downloading discogs_client-2.3.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from discogs_client) (1.15.0)
# Requirement already satisfied: oauthlib in /usr/local/lib/python3.7/dist-packages (from discogs_client) (3.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from discogs_client) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->discogs_client) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->discogs_client) (2.10)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 5.1 MB/s
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->discogs_client) (3.0.4)
# Installing collected packages: urllib3, discogs-client
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.8
#     Uninstalling urllib3-1.26.8:
#       Successfully uninstalled urllib3-1.26.8
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# selenium 4.1.2 requires urllib3[secure,socks]~=1.26, but you have urllib3 1.25.11 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed discogs-client-2.3.0 urllib3-1.25.11
# Collecting unidecode
#   Downloading Unidecode-1.3.3-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 5.4 MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.3
# Requirement already satisfied: selenium in /usr/local/lib/python3.7/dist-packages (4.1.2)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.7/dist-packages (from selenium) (0.20.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.7/dist-packages (from selenium) (0.9.2)
# Collecting urllib3[secure,socks]~=1.26
#   Using cached urllib3-1.26.8-py2.py3-none-any.whl (138 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: async-generator>=1.9 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.7/dist-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (22.0.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: cryptography>=1.3.4 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (36.0.1)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from h11<1,>=0.9.0->wsproto>=0.14->trio-websocket~=0.9->selenium) (3.10.0.2)
# Installing collected packages: urllib3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.11
#     Uninstalling urllib3-1.25.11:
#       Successfully uninstalled urllib3-1.25.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.8 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed urllib3-1.26.8
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:6 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [76.8 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:9 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Ign:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:11 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Ign:12 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:13 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,827 kB]
# Get:14 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,035 kB]
# Hit:16 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [806 kB]
# Get:18 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [840 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,252 kB]
# Get:21 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,474 kB]
# Get:22 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [936 kB]
# Get:23 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,596 kB]
# Get:24 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [42.8 kB]
# Get:26 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [931 kB]
# Fetched 15.1 MB in 4s (3,528 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-470
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 75 not upgraded.
# Need to get 95.3 MB of archives.
# After this operation, 327 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 97.0.4692.71-0ubuntu0.18.04.1 [1,142 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 97.0.4692.71-0ubuntu0.18.04.1 [84.7 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser-l10n all 97.0.4692.71-0ubuntu0.18.04.1 [4,370 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-chromedriver amd64 97.0.4692.71-0ubuntu0.18.04.1 [5,055 kB]
# Fetched 95.3 MB in 4s (24.1 MB/s)
# Selecting previously unselected package chromium-codecs-ffmpeg-extra.
# (Reading database ... 155320 files and directories currently installed.)
# Preparing to unpack .../chromium-codecs-ffmpeg-extra_97.0.4692.71-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-codecs-ffmpeg-extra (97.0.4692.71-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser.
# Preparing to unpack .../chromium-browser_97.0.4692.71-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-browser (97.0.4692.71-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-browser-l10n.
# Preparing to unpack .../chromium-browser-l10n_97.0.4692.71-0ubuntu0.18.04.1_all.deb ...
# Unpacking chromium-browser-l10n (97.0.4692.71-0ubuntu0.18.04.1) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_97.0.4692.71-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking chromium-chromedriver (97.0.4692.71-0ubuntu0.18.04.1) ...
# Setting up chromium-codecs-ffmpeg-extra (97.0.4692.71-0ubuntu0.18.04.1) ...
# Setting up chromium-browser (97.0.4692.71-0ubuntu0.18.04.1) ...
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium-browser to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-chromedriver (97.0.4692.71-0ubuntu0.18.04.1) ...
# Setting up chromium-browser-l10n (97.0.4692.71-0ubuntu0.18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file

# %%
import pandas as pd
import numpy as np

import base64
import os
import time

from requests import get
from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.common.exceptions import NoSuchElementException
import discogs_client

from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from google.colab import files

from os import path
# Out:
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
sys.path.insert(0,'/content/gdrive/My Drive/CroLyrics_data')
# Out:
# Mounted at /content/gdrive

# %%
from utils import lower_and_remove_diacritics, check_row_similariy, similar

# %%
def scrape_tekstovinet(artist, diskografija_artist_name, url_teksovinet):
    # Scraping tekstovi.net for song lyrics by artist (change url to change artist)
    delay = 2

    ## Create empty df:
    column_names = ["Song_ID", "Artist", "Artist_diskografija", "Song_tekstovinet", "Views_tekstovinet", "Lyrics_tekstovinet", "Url_tekstovinet"]
    df = pd.DataFrame(columns = column_names)


    # generate random artist ID and make sure it doesnt have '_'
    artist_ID = base64.b64encode(os.urandom(6)).decode('ascii')
    while(artist_ID.find('_')>=0):
        artist_ID = base64.b64encode(os.urandom(6)).decode('ascii')
        
    response = get(url_teksovinet)
    html_soup = BeautifulSoup(response.text, 'html.parser')
    songs = html_soup.find_all('p', class_='artLyrList')


    for index, song in enumerate(songs):
        song_name = song.findChild("a").text
        song_url = song.findChild("a")["href"]

        url = 'https://tekstovi.net/'+song_url

        response = get(url)
        html_soup = BeautifulSoup(response.text, 'html.parser')

        song_lyrics = html_soup.find_all('p', class_='lyric')
        lyrics = [l.text for l in song_lyrics]
        lyrics = " ".join(lyrics)
        song_ID = artist_ID + '_' + str(1) + '_' + str(index)
        views_text = html_soup.find('p', class_='lyric_impressions').text
        views_count = int("".join([c for c in views_text if c.isdigit()]))
        new_entry = pd.DataFrame([[song_ID, artist, diskografija_artist_name, song_name, views_count, lyrics, url]], columns=["Song_ID", "Artist", "Artist_diskografija", "Song_tekstovinet", "Views_tekstovinet", "Lyrics_tekstovinet", "Url_tekstovinet"])
        df = df.append(new_entry, ignore_index=True)

        print("Lyrics successfully written to file for : " + song_name)
                            
        time.sleep(delay)

    df.to_csv(f"/content/gdrive/My Drive/CroLyrics_data/{artist_name}_tekstovinet.csv", index=False)

# %%
def search_google(search_query, driver):
    driver.find_element(By.NAME, 'q').clear()
    search_box = driver.find_element(By.NAME, 'q')
    search_box.send_keys(search_query)
    search_box.send_keys(Keys.RETURN)
    time.sleep(3)

# %%
def get_lyricstranslate(driver):
    
    driver.find_element(By.PARTIAL_LINK_TEXT, 'lyricstranslate.com').send_keys(Keys.CONTROL + Keys.RETURN)
    time.sleep(0.5)
    window_handles = driver.window_handles
    driver.switch_to.window(window_name=window_handles[1])    
    time.sleep(1)


    try: driver.find_element(By.XPATH, "//*[contains(text(), 'AGREE')]").click()
    except NoSuchElementException: pass
    time.sleep(0.5)
    
    try: driver.find_element(By.PARTIAL_LINK_TEXT, 'English').click()
    except NoSuchElementException: pass
    time.sleep(0.5)

    try: driver.find_element(By.PARTIAL_LINK_TEXT, 'Click to see the original lyrics').click()
    except NoSuchElementException: pass
    time.sleep(0.5)
    
    
    try:
        original_lyrics_raw = driver.find_element(By.CLASS_NAME, 'song-node-text')
        original_title = original_lyrics_raw.find_element(By.CLASS_NAME, 'title-h2').text
        par_class = original_lyrics_raw.find_elements(By.CLASS_NAME, 'par')
        original_lyrics = ". ".join([t.text for t in par_class])
        original_lyrics = original_lyrics.replace("*", "")
        try:
          copyright = original_lyrics_raw.find_element(By.CLASS_NAME, 'copyrighttext').text.split("\n")
          writer_info = [c for c in copyright if "Writer" in c]
          if len(writer_info)>0:
            writer = writer_info[0].split(": ")[1]
          else: 
            print("Couldn't find writer info")
            writer = np.nan
    
        except NoSuchElementException: 
          print("Couldn't find writer info")
          writer = np.nan


    except NoSuchElementException:
        print("Couldn't find original lyrics")
        original_title = np.nan
        original_lyrics = np.nan
        writer = np.nan

    try:
        eng_lyrics_raw = driver.find_element(By.CLASS_NAME, 'translate-node-text')
        eng_title = eng_lyrics_raw.find_element(By.CLASS_NAME, 'title-h2').text
        par_class = eng_lyrics_raw.find_elements(By.CLASS_NAME, 'par')
        eng_lyrics = ". ".join([t.text for t in par_class])
        eng_lyrics = eng_lyrics.replace("*", "")
    except NoSuchElementException:
        print("Couldn't find english lyrics")
        eng_title = np.nan
        eng_lyrics = np.nan



    try:
        song_info = driver.find_element(By.CLASS_NAME, 'song-node-info')
        album_name = song_info.find_element(By.XPATH, "//*[contains(text(), 'Album')]").text
        if len(album_name)>0:
            album_name = album_name.split(": ")
            if len(album_name)>1:
              album_name = album_name[1]
            else:
              print("Couldn't extract album info from string:")
              print(album_name)
        else: 
            print("Couldn't find album info")
            album_name =np.nan
    except NoSuchElementException: 
        print("Couldn't find album info")
        album_name = np.nan

    
    song_url = driver.current_url
    driver.close()
    driver.switch_to.window(window_name=window_handles[0])
    
    
    return writer, original_title, eng_title, album_name, original_lyrics, eng_lyrics, song_url

# %%
def scrape_lyricstranslate(artist_name):
    df = pd.read_csv(f"/content/gdrive/My Drive/CroLyrics_data/{artist_name}_tekstovinet.csv")

    ser = Service()
    op = webdriver.ChromeOptions()
    op.add_argument('--headless')
    op.add_argument('--no-sandbox')
    op.add_argument('--disable-dev-shm-usage')

 


    driver = webdriver.Chrome(service=ser, options=op)
    driver.get("https://google.com")
    time.sleep(3)
    
    try: driver.find_element(By.ID, 'L2AGLb').click()  ##Accepting the cookies if necessary
    except: pass

    #try: driver.find_element(By.XPATH, "//*[contains(text(), 'I agree')]").click()
    #except: driver.find_element(By.XPATH, "//*[contains(text(), 'Aceito')]").click()
    #except Exception as e: print(e)
    time.sleep(0.5)

    try: 
      driver.find_element(By.XPATH, "//*[contains(text(), 'English')]").click()
    except: pass
    time.sleep(0.5)

    df_new = df.copy()#[71:]##[16:17]
    for row in df_new.iterrows():
        time.sleep(1)
        artist_name = row[1].Artist
        song_name = row[1].Song_tekstovinet
        try: song_name = song_name[0:song_name.index("(")]
        except:pass
        
        try:
            search_google(artist_name+" "+song_name+ " english lyricstranslate", driver)
            writer, original_title, eng_title, album_name, original_lyrics, eng_lyrics, song_url = get_lyricstranslate(driver)

            df.loc[row[0], "Writer_lyricstranslate"] = writer 
            df.loc[row[0], "Song_lyricstranslate"] = original_title
            df.loc[row[0], "EngTitle_lyricstranslate"] = eng_title
            df.loc[row[0], "Album_lyricstranslate"] = album_name
            df.loc[row[0], "Lyrics_lyricstranslate"] = original_lyrics
            df.loc[row[0], "EngLyrics_lyricstranslate"] = eng_lyrics
            df.loc[row[0], "Url_lyricstranslate"] = song_url

            print(f"Succesfully found information for {song_name} from {artist_name}")
        
        except NoSuchElementException:  print(f"Couldn't find lyrics for song {song_name} by {artist_name} from lyricstranslate.com")
    
        print("#######")
        time.sleep(3)

    wrong_rows = check_row_similariy(df, "Lyrics_tekstovinet", "Lyrics_lyricstranslate", threshold=0.7)
    
    ##set parameters as nan for wrong rows
    for row in wrong_rows:
        df.loc[row, "Writer_lyricstranslate"] = np.nan
        df.loc[row, "Song_lyricstranslate"] = np.nan
        df.loc[row, "EngTitle_lyricstranslate"] = np.nan
        df.loc[row, "Album_lyricstranslate"] = np.nan
        df.loc[row, "Lyrics_lyricstranslate"] = np.nan
        df.loc[row, "EngLyrics_lyricstranslate"] = np.nan
        df.loc[row, "Url_lyricstranslate"] = np.nan

    df.to_csv(f"/content/gdrive/My Drive/CroLyrics_data/{artist_name}_tekstovinet_lyricstranslate.csv", index=False)
    driver.quit()

# %%
def scrape_for_authors_and_albums(song_name, artist_name, driver):
    #search
    driver.find_element(By.CLASS_NAME, 'search-page').clear()
    search_box = driver.find_element(By.CLASS_NAME, 'search-page')
    song_name = lower_and_remove_diacritics(song_name)
    search_box.send_keys(song_name)
    search_box.send_keys(Keys.RETURN)
    time.sleep(2)
    

    try:
        song_results = driver.find_element(By.XPATH, f"//*[contains(text(), 'Pjesme')]/following-sibling::ul")
        song_results = song_results.find_elements(By.TAG_NAME, 'a')
        #go through search results
        for song in song_results:

            song.send_keys(Keys.CONTROL + Keys.RETURN)
            window_handles = driver.window_handles

            driver.switch_to.window(driver.window_handles[1])
            time.sleep(1)            

            if  check_performer(artist_name, driver):
                subfields, authors = get_authors(driver)
                albums = get_albums(driver)
                song_url = driver.current_url
                song_name_website = driver.find_element(By.XPATH, f"//*[contains(text(), 'Pjesma')]/following-sibling::h1").text
                driver.close()
                driver.switch_to.window(window_name=window_handles[0])
                return subfields, authors, albums, song_url, song_name_website
                
            else:
                driver.close()
                driver.switch_to.window(window_name=window_handles[0])
        print(f"No info for the song {song_name} by {artist_name} on diskografija.com")
        return False
    
    except NoSuchElementException: 
      print(f"No info for the song {song_name} by {artist_name} on diskografija.com")
      return False

# %%
def check_performer(artist_name, driver):
    authors = driver.find_elements(By.TAG_NAME, "h3")[1:]
    artist_name = lower_and_remove_diacritics(artist_name)
    result = []
    for index, author in enumerate(authors):
        subfield = author.text.capitalize()
        if subfield == "Izvedba":
            siblings_of_current = driver.find_elements(By.XPATH, f"//*[contains(text(), '{subfield}')]/following-sibling::a")
            if index<len(authors)-1: 
                siblings_of_next = driver.find_elements(By.XPATH, f"//*[contains(text(), '{authors[index+1].text.capitalize()}')]/following-sibling::a")
                result = [r.text for r in siblings_of_current[0: len(siblings_of_current)-len(siblings_of_next)]]
            else: result = [r.text for r in siblings_of_current] 
        
    return True if len([r for r in result if artist_name in lower_and_remove_diacritics(r)])>0 else False

# %%
def get_authors(driver):
    all_fields = []
    all_authors = []
    authors = driver.find_elements(By.XPATH, f"//*[contains(text(), 'Autori')]/following-sibling::h3")
    for index, author in enumerate(authors):
        subfield = author.text.capitalize()
        siblings_of_current = driver.find_elements(By.XPATH, f"//*[contains(text(), '{subfield}')]/following-sibling::a")
        if len(siblings_of_current)>0:
            if index<len(authors)-1: 
                siblings_of_next = driver.find_elements(By.XPATH, f"//*[contains(text(), '{authors[index+1].text.capitalize()}')]/following-sibling::a")
                result = [r.text for r in siblings_of_current[0: len(siblings_of_current)-len(siblings_of_next)]]
            else: result = [r.text for r in siblings_of_current]
            all_fields.append(subfield)
            all_authors.append(str(result))
            
    return all_fields, all_authors

# %%
def get_albums(driver):
    albums = driver.find_elements(By.XPATH, f"//*[contains(text(), 'Albumi')]/following-sibling::div")
    return [{album.text} for album in albums]

# %%
def scrape_diskografija(artist_name):
    df = pd.read_csv(f"/content/gdrive/My Drive/CroLyrics_data/{artist_name}_tekstovinet_lyricstranslate.csv")
    
    ser = Service()
    op = webdriver.ChromeOptions()
    op.add_argument('--headless')
    op.add_argument('--no-sandbox')
    op.add_argument('--disable-dev-shm-usage')

    driver = webdriver.Chrome(service=ser, options=op)
    driver.get("https://diskografija.com/")

   
    df_new = df.copy()#[21:]
    for row in df_new.iterrows():
        artist_name_diskografija = row[1].Artist_diskografija
        song_name = row[1].Song_lyricstranslate
        if type(song_name)==float: song_name = row[1].Song_tekstovinet
        try: song_name = song_name[0:song_name.index("(")]
        except:pass
        
 
        try:
          subfields, authors, albums, song_url, song_title_website = scrape_for_authors_and_albums(song_name, artist_name_diskografija, driver)
          
          if subfields:
            for subfield, author in zip(subfields, authors):
                df.loc[row[0], f"{subfield}_diskografija"] = author
                    
            for i, album in enumerate(albums):
                df.loc[row[0], f"Album_{i+1}_diskografija"] = album
            df.loc[row[0], "Url_diskografija"] = song_url
            df.loc[row[0], "Song_diskografija"] = song_title_website

            print(f"Succesfully found information for {song_name} from {artist_name}")
          
        except TypeError: pass
          
        print("#######")
        time.sleep(3)
        

    df.to_csv(f"/content/gdrive/My Drive/CroLyrics_data/{artist_name}_tekstovinet_lyricstranslate_diskografija.csv")

    driver.quit()

# %%
def scrape_cuspajz(artist_name, url_cuspajz):
    df = pd.read_csv(f"/content/gdrive/My Drive/CroLyrics_data/{artist_name}_tekstovinet_lyricstranslate_diskografija.csv")

    # Scraping cuspajz.com for song lyrics by artist

    response = get(url_cuspajz)
    html_soup = BeautifulSoup(response.text, 'html.parser')

    # Get the list of songs
    songs = html_soup.find_all('ul', class_='songList')

    song_names = []
    song_urls = []
    for col_index, column in enumerate(songs):
        songs = column.find_all('li')
        for index, song in enumerate(songs):
            song_names.append(song.a.text)
            song_urls.append(song.a['href'])


    similarity_threshold = 0.9
    for row in df.iterrows():
        song_title = lower_and_remove_diacritics(row[1].Song_tekstovinet).split('(')[0]
        similarities = [similar(song_title, lower_and_remove_diacritics(s.split('(')[0])) for s in song_names]
        max_similarity = max(similarities)
        
        if max_similarity>similarity_threshold:
            cuspajz_name = song_names[similarities.index(max_similarity)] 
            song_url = song_urls[similarities.index(max_similarity)]
            url = 'https://cuspajz.com/'+song_url

            response = get(url)
            html_soup = BeautifulSoup(response.text, 'html.parser')

            song_lyrics = html_soup.find('p', class_='clearfix')
            lyrics =  song_lyrics.get_text()
            
            df.loc[row[0], "Lyrics_cuspajz"] = lyrics
            df.loc[row[0], "Song_cuspajz"] = cuspajz_name
            df.loc[row[0], "Url_cuspajz"] = url
            

            print("Lyrics successfully written to file for : " + song_title)          
            time.sleep(3)

        else:
            print(f"Couldn't find lyrics for song {song_title} on cuspajz.com")
            

    wrong_rows = check_row_similariy(df, "Lyrics_tekstovinet", "Lyrics_cuspajz", threshold=0.7)
    ##set parameters as nan for wrong rows
    for row in wrong_rows:
        df.loc[row, "Lyrics_cuspajz"] = np.nan
        df.loc[row, "Song_cuspajz"] = np.nan
        df.loc[row, "Url_cuspajz"] = np.nan

    df.to_csv(f"/content/gdrive/My Drive/CroLyrics_data/{artist_name}_tekstovinet_lyricstranslate_diskografija_cuspajz.csv", index=False)

# %%
def scrape_discogs(artist_name, artist_id_discogs):
    d = discogs_client.Client('datamilas/0.1', user_token='BDGKHOLMZJxywoowKXvyRhXeqJhkezYxwVjxvBJR')
    artist_object = d.artist(artist_id_discogs)
    artist_discogs = artist_object.name
    albums = artist_object.releases
    df_discogs = pd.DataFrame(columns=["Artist"])


    i=0
    for album in albums:
      try:
        if album.data["role"] == "Main":
            print(album)
            time.sleep(2)
            
            if "tracklist" in dir(album):
              for track in album.tracklist:
                  if "title" in dir(track):
                      df_discogs.loc[i, "Artist"] = artist_name
                      df_discogs.loc[i, "Artist_discogs"] = artist_discogs
                      df_discogs.loc[i, "Song_discogs"] = track.title

                      if "duration" in track.data.keys(): df_discogs.loc[i, "Song_duration_discogs"] = track.data["duration"]
                      if "extraartists" in track.data.keys():
                          for ea in track.data["extraartists"]:
                              roles = ea["role"].split(", ")

                              for role in roles:
                                  try: df_discogs.loc[i, f"{role}_discogs"] = df_discogs.loc[i, role]+"/"+ea["name"]
                                  except: df_discogs.loc[i, f"{role}_discogs"] = ea["name"]
                      
                      if "title" in dir(album): df_discogs.loc[i, "Album_title_discogs"] = album.title
                      if "year" in dir(album): df_discogs.loc[i, "Album_year_discogs"] = album.year
                      if "genre" in dir(album): df_discogs.loc[i, "Album_genres_discogs"] = str(album.genres)

                      i+=1
      except Exception as e: print(e)

    df_discogs["Album_year_title_discogs"] = df_discogs["Album_year_discogs"].astype(str)+"-"+df_discogs["Album_title_discogs"]
    df_discogs["All_albums_discogs"] = df_discogs.groupby("Song_discogs")["Album_year_title_discogs"].transform(lambda x: '/'.join(x))

    df_discogs.sort_values("Album_year_discogs").reset_index(drop=True, inplace=True)
    df_discogs = df_discogs.drop_duplicates(subset=["Song_discogs"])
    df_discogs = df_discogs.reset_index(drop=True)

    columns_to_take = [col for col in df_discogs.columns if col in ['Artist_discogs', 'Song_discogs', 'Song_duration_discogs',
       'Album_title_discogs', 'Album_year_discogs', 'Album_genres_discogs','All_albums_discogs',
       'Lyrics By_discogs', 'Music By_discogs', 'Featuring_discogs']]

    df = pd.read_csv(f"/content/gdrive/My Drive/CroLyrics_data/{artist_name}_tekstovinet_lyricstranslate_diskografija_cuspajz.csv")

    similarity_threshold = 0.9
    song_names = [lower_and_remove_diacritics(s).split('(')[0] for s in df_discogs.Song_discogs]
    for row in df.iterrows():
        song_title = lower_and_remove_diacritics(row[1].Song_tekstovinet).split('(')[0]
        similarities = [similar(song_title, s) for s in song_names]
        max_similarity = max(similarities)
        
        if max_similarity>similarity_threshold:
            df.loc[row[0], columns_to_take] = df_discogs.loc[similarities.index(max_similarity)][columns_to_take]


    df.to_csv(f"/content/gdrive/My Drive/CroLyrics_data/{artist_name}_final.csv", index=False)
    df_discogs.to_csv(f"/content/gdrive/My Drive/CroLyrics_data/{artist_name}_discogs.csv", index=False)

# %%
df = pd.read_csv(f"/content/gdrive/My Drive/CroLyrics_data/info_for_scraping.csv")

# %%
for row in df.iterrows():
    artist_name = row[1].artist_name
    artist_name_diskografija = row[1].artist_name_diskografija
    url_tekstovinet = row[1].url_tekstovinet
    url_cuspajz = row[1].url_cuspajz
    artist_id_discogs = row[1].artist_id_discogs

    if not path.exists(f"/content/gdrive/My Drive/CroLyrics_data/{artist_name}_tekstovinet.csv"):
      scrape_tekstovinet(artist_name, artist_name_diskografija, url_tekstovinet)

    if not path.exists(f"/content/gdrive/My Drive/CroLyrics_data/{artist_name}_tekstovinet_lyricstranslate.csv"):
      scrape_lyricstranslate(artist_name)

    if not path.exists(f"/content/gdrive/My Drive/CroLyrics_data/{artist_name}_tekstovinet_lyricstranslate_diskografija.csv"):
      scrape_diskografija(artist_name)

    if not path.exists(f"/content/gdrive/My Drive/CroLyrics_data/{artist_name}_tekstovinet_lyricstranslate_diskografija_cuspajz.csv"):
      scrape_cuspajz(artist_name, url_cuspajz)

    if not path.exists(f"/content/gdrive/My Drive/CroLyrics_data/{artist_name}_discogs.csv"):
      scrape_discogs(artist_name, artist_id_discogs)
# Out:
# <Release 2481214 "Rock 'N' Roll / Jedina Moja">
# <Release 3103801 'Moj Dilbere / Prijatelj'>
# <Release 3045677 'Patkica / Kad Bi Vi Gospođo'>
# <Master 331485 'Divlje Jagode'>
# <Release 2303777 "Nemam Ništa Protiv / Bit' Će Bolje!">
# <Master 419321 'Stakleni Hotel'>
# <Master 351568 'Motori'>
# <Master 284175 'Čarobnjaci'>
# <Master 286042 'Vatra'>
# <Master 428180 'Najbolje'>
# <Release 2963545 'Turski Marš / Konji'>
# <Master 419324 'Konji'>
# <Master 591867 'Labude Kad Rata Ne Bude '>
# <Master 1306519 'Antologija 2'>
# <Master 636709 'Antologija 1'>
# <Master 419325 'Sto Vjekova'>
# <Master 1192073 'The Best Of'>
# <Release 7428145 'Marija'>
# <Release 7428169 'Dobro Došla Ljubavi'>
# <Master 419323 'Od Neba Do Neba'>
# <Master 1811296 'The Very Best Of'>
# <Release 5962817 'The Very Best Of - Let Na Drugi Svijet'>
# <Release 7440456 'Live + video clips'>
# <Release 15940900 'Najlepše Balade - Krivo Je More'>
# <Master 813675 'The Very Best Of - Let Na Drugi Svijet'>
# <Release 6264345 'Collection'>
# <Master 607752 'Piramida'>
# <Master 428574 'Wild Strawberries'>
# <Master 1341144 'Collection'>
# <Release 3920446 'The Ultimate Collection'>
# <Master 1299408 'The Ultimate Collection'>
# <Release 3153059 'Ne, Nisam Ja'>
# <Release 7073246 'Najljepše Ljubavne Pjesme - The Love Collection'>
# <Master 1150806 'Biodinamička Ljubav'>
# <Master 1341143 'Greatest Hits'>
# <Release 8450305 'Evo Banke Cigane Moj'>
# <Release 12705874 'Original Album Collection Vol. 1'>
# <Release 12705944 'Original Album Collection Vol. 2'>
# <Master 1679886 'Jukebox'>
# <Release 22028728 'Plave Noći Bez Tebe'>
# Lyrics successfully written to file for : A ti se neces vratiti
# Lyrics successfully written to file for : Ajmo tugo, ajmo tamburasi
# Lyrics successfully written to file for : Andjeli
# Lyrics successfully written to file for : Bagremi su procvjetali
# Lyrics successfully written to file for : Becar, to je zvanje
# Lyrics successfully written to file for : Bit ce bolje
# Lyrics successfully written to file for : Da smo prije znali
# Lyrics successfully written to file for : Da smo ranije se sreli
# Lyrics successfully written to file for : Dan po dan
# Lyrics successfully written to file for : Dat ce Bog i bolje dane (& Vedrana Vukojevic)
# Lyrics successfully written to file for : Did Luka
# Lyrics successfully written to file for : Djevojka iz Valpova
# Lyrics successfully written to file for : Do dna duse
# Lyrics successfully written to file for : Dok je ljubav
# Lyrics successfully written to file for : Ej, kavane
# Lyrics successfully written to file for : Ivana
# Lyrics successfully written to file for : Ja pijem da zaboravim
# Lyrics successfully written to file for : Ja te volim najvise
# Lyrics successfully written to file for : Jos i danas zamirise tresnja
# Lyrics successfully written to file for : Jos se nadam bit' ce bolje
# Lyrics successfully written to file for : Kad zasuti moja tambura
# Lyrics successfully written to file for : Kako ljubav vratiti
# Lyrics successfully written to file for : Kisa pada
# Lyrics successfully written to file for : Laze selo, lazu ljudi
# Lyrics successfully written to file for : Ljubav i grijeh
# Lyrics successfully written to file for : Ljubavi
# Lyrics successfully written to file for : Lutalica
# Lyrics successfully written to file for : Mirta
# Lyrics successfully written to file for : Moja luda glava
# Lyrics successfully written to file for : Nabujale strasti
# Lyrics successfully written to file for : Najdraza moja
# Lyrics successfully written to file for : Ne daj da nam prodje vrijeme
# Lyrics successfully written to file for : Ne luduj
# Lyrics successfully written to file for : Ne mogu ti reci zbogom
# Lyrics successfully written to file for : Nek pjesma ostane
# Lyrics successfully written to file for : Nek' se znade ko je pravi gazda
# Lyrics successfully written to file for : Neka me boli
# Lyrics successfully written to file for : Nemoj u moj san
# Lyrics successfully written to file for : Nije jutro krivo
# Lyrics successfully written to file for : Nije meni zao
# Lyrics successfully written to file for : Nije nam od Boga dano
# Lyrics successfully written to file for : Nocas
# Lyrics successfully written to file for : Ostale i vece ljubavi bez srece
# Lyrics successfully written to file for : Ostarit cu ja, ostarit ces ti
# Lyrics successfully written to file for : Pazi duso
# Lyrics successfully written to file for : Poslije kise sunce dolazi
# Lyrics successfully written to file for : Prerano, prerano
# Lyrics successfully written to file for : Previse je bola na dnu duse moje
# Lyrics successfully written to file for : Prorekli te
# Lyrics successfully written to file for : Sacuvaj mene za sebe
# Lyrics successfully written to file for : Samujem, tugujem
# Lyrics successfully written to file for : Sedmica
# Lyrics successfully written to file for : Sto sam Bogu skrivio
# Lyrics successfully written to file for : Tesko onom koga zale
# Lyrics successfully written to file for : Ti si jos premlada
# Lyrics successfully written to file for : Trebam te nocas
# Lyrics successfully written to file for : Tudji svatovi
# Lyrics successfully written to file for : U ljubavi srece nemam
# Lyrics successfully written to file for : U snu i ljubavi
# Lyrics successfully written to file for : Usne boje vina
# Lyrics successfully written to file for : Vazda gazda
# Lyrics successfully written to file for : Za ljubav tvoju
# Lyrics successfully written to file for : Za tebe
# Lyrics successfully written to file for : Zagorska
# Lyrics successfully written to file for : Zaplakat ces
# Lyrics successfully written to file for : Zauvijek
# Lyrics successfully written to file for : Zbog tebe sam to sto jesam
# Lyrics successfully written to file for : Zbogom za zbogom
# Lyrics successfully written to file for : Zoro, vec mi svanulo
# Couldn't find writer info
# Couldn't find album info
# Succesfully found information for A ti se neces vratiti from Gazde
# #######
# Couldn't find original lyrics
# Couldn't find english lyrics
# Couldn't find album info
# Succesfully found information for Ajmo tugo, ajmo tamburasi from Gazde
# #######
# Couldn't find original lyrics
# Couldn't find english lyrics
# Couldn't find album info
# Succesfully found information for Andjeli from Gazde
# #######
# Couldn't find original lyrics
# Couldn't find english lyrics
# Couldn't find album info
# Succesfully found information for Bagremi su procvjetali from Gazde
# #######
# Couldn't find original lyrics
# Couldn't find english lyrics
# Couldn't find album info
# Succesfully found information for Becar, to je zvanje from Gazde
# #######
# Couldn't find writer info
# Succesfully found information for Bit ce bolje from Gazde
# #######
# Couldn't find original lyrics
# Couldn't find english lyrics
# Couldn't find album info
# Succesfully found information for Da smo prije znali from Gazde
# #######
# Couldn't find writer info
# Couldn't find album info
# Succesfully found information for Da smo ranije se sreli from Gazde
# #######
# Couldn't find original lyrics
# Couldn't find english lyrics
# Couldn't find album info
# Succesfully found information for Dan po dan from Gazde
# #######
# Couldn't find lyrics for song Dat ce Bog i bolje dane  by Gazde from lyricstranslate.com
# #######
# Couldn't find original lyrics
# Couldn't find english lyrics
# Couldn't find album info
# Succesfully found information for Did Luka from Gazde
# #######
# Couldn't find lyrics for song Djevojka iz Valpova by Gazde from lyricstranslate.com
# #######
# Couldn't find original lyrics
# Couldn't find english lyrics
# Couldn't find album info
# Succesfully found information for Do dna duse from Gazde
# #######
# Couldn't find original lyrics
# Couldn't find english lyrics
# Couldn't find album info
# Succesfully found information for Dok je ljubav from Gazde
# #######
# Couldn't find writer info
# Couldn't find album info
# Succesfully found information for Ej, kavane from Gazde
# #######
# Couldn't find writer info
# Couldn't find album info
# Succesfully found information for Ivana from Gazde
# #######
# Couldn't find writer info
# Couldn't find album info
# Succesfully found information for Ja pijem da zaboravim from Gazde
# #######
# Couldn't find writer info
# Couldn't find album info
# Succesfully found information for Ja te volim najvise from Gazde
# #######
# Couldn't find writer info
# Couldn't find album info
# Succesfully found information for Jos i danas zamirise tresnja from Gazde
# #######
# Couldn't find original lyrics
# Couldn't find english lyrics
# Couldn't find album info
# Succesfully found information for Jos se nadam bit' ce bolje from Gazde
# #######
# Couldn't find lyrics for song Kad zasuti moja tambura by Gazde from lyricstranslate.com
# #######
# Couldn't find album info
# Succesfully found information for Kako ljubav vratiti from Gazde
# #######
# Couldn't find album info
# Succesfully found information for Kisa pada from Gazde
# #######
# Couldn't find writer info
# Couldn't find album info
# Succesfully found information for Laze selo, lazu ljudi from Gazde
# #######
# Couldn't find original lyrics
# Couldn't find english lyrics
# Couldn't find album info
# Succesfully found information for Ljubav i grijeh from Gazde
# #######
# Couldn't find writer info
# Couldn't find album info
# Succesfully found information for Ljubavi from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Succesfully found information for Lutalica from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Succesfully found information for Mirta from Gazde
# #######
# Couldn't find album info
# Succesfully found information for Moja luda glava from Gazde
# #######
# Couldn't find original lyrics
# Couldn't find english lyrics
# Couldn't find album info
# Succesfully found information for Nabujale strasti from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Succesfully found information for Najdraza moja from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Succesfully found information for Ne daj da nam prodje vrijeme from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Succesfully found information for Ne luduj from Gazde
# #######
# Couldn't find writer info
# Couldn't find album info
# Succesfully found information for Ne mogu ti reci zbogom from Gazde
# #######
# Couldn't find lyrics for song Nek pjesma ostane by Gazde from lyricstranslate.com
# #######
# Couldn't find writer info
# Couldn't find album info
# Succesfully found information for Nek' se znade ko je pravi gazda from Gazde
# #######
# Couldn't find writer info
# Couldn't find album info
# Succesfully found information for Neka me boli from Gazde
# #######
# Couldn't find album info
# Succesfully found information for Nemoj u moj san from Gazde
# #######
# Couldn't find lyrics for song Nije jutro krivo by Gazde from lyricstranslate.com
# #######
# Couldn't find album info
# Succesfully found information for Nije meni zao from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Couldn't find album info
# Succesfully found information for Nije nam od Boga dano from Gazde
# #######
# Couldn't find writer info
# Couldn't find album info
# Succesfully found information for Nocas from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Succesfully found information for Ostale i vece ljubavi bez srece from Gazde
# #######
# Couldn't find writer info
# Couldn't find album info
# Succesfully found information for Ostarit cu ja, ostarit ces ti from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Succesfully found information for Pazi duso from Gazde
# #######
# Couldn't find writer info
# Couldn't find album info
# Succesfully found information for Poslije kise sunce dolazi from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Succesfully found information for Prerano, prerano from Gazde
# #######
# Couldn't find album info
# Succesfully found information for Previse je bola na dnu duse moje from Gazde
# #######
# Couldn't find original lyrics
# Couldn't find english lyrics
# Couldn't find album info
# Succesfully found information for Prorekli te from Gazde
# #######
# Succesfully found information for Sacuvaj mene za sebe from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Succesfully found information for Samujem, tugujem from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Succesfully found information for Sedmica from Gazde
# #######
# Couldn't find writer info
# Couldn't find album info
# Succesfully found information for Sto sam Bogu skrivio from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Succesfully found information for Tesko onom koga zale from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Succesfully found information for Ti si jos premlada from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Couldn't find album info
# Succesfully found information for Trebam te nocas from Gazde
# #######
# Couldn't find writer info
# Couldn't find album info
# Succesfully found information for Tudji svatovi from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Succesfully found information for U ljubavi srece nemam from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Couldn't find album info
# Succesfully found information for U snu i ljubavi from Gazde
# #######
# Couldn't find writer info
# Succesfully found information for Usne boje vina from Gazde
# #######
# Couldn't find album info
# Succesfully found information for Vazda gazda from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Succesfully found information for Za ljubav tvoju from Gazde
# #######
# Couldn't find writer info
# Succesfully found information for Za tebe from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Succesfully found information for Zagorska from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Succesfully found information for Zaplakat ces from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Succesfully found information for Zauvijek from Gazde
# #######
# Couldn't find writer info
# Couldn't find album info
# Succesfully found information for Zbog tebe sam to sto jesam from Gazde
# #######
# Couldn't find writer info
# Couldn't find album info
# Succesfully found information for Zbogom za zbogom from Gazde
# #######
# Couldn't find writer info
# Couldn't find english lyrics
# Succesfully found information for Zoro, vec mi svanulo from Gazde
# #######
# jos jedan dan u zagrebu vozim se u tramvajuide masa praznih dzepovana ovom svijetu nikoga pogled ravno nevjeranema kune za prosjaka i dok tako sanjarimshvatih ovdje silazimguram se do izlazaal tu je hrpa likovavozac vrata zatvarajos jedan krug u tramvajurefeto vidis to je moja sudbinauvijek isto bezbroj praznih krugovabozja volja kriza mladih umovabit ce bolje moram prezivjet do sutrajos jedan dan u zagrebumagla je na sljemenupljusti kisa jesenjabrdo tmurnih oblaka odurna vodurinamore je pod nogamastojim sam na krizanjuopet znam zakasnit cuvidim gori crvenocekam tako strpljivo prodje taxi prebrzoi cijeloga me zaspricaref
Krunoslav Kićo Slabinac
# #######
# Succesfully found information for Seoska Sam Lola from Krunoslav Kićo Slabinac
# #######
# Succesfully found information for Serenada  from Krunoslav Kićo Slabinac
# #######
# Succesfully found information for Sinoc bila misecina from Krunoslav Kićo Slabinac
# #######
# No info for the song skripi djeram by Kićo on diskografija.com
# #######
# Succesfully found information for Slavonac sam from Krunoslav Kićo Slabinac
# #######
# Succesfully found information for Slavonijo, ja sam tvoje dijete from Krunoslav Kićo Slabinac
# #######
# No info for the song slavonijo, kuco stara by Kićo on diskografija.com
# #######
# No info for the song slavonski taraban by Kićo on diskografija.com
# #######
# Succesfully found information for Slavonsko kolo from Krunoslav Kićo Slabinac
# #######
# Succesfully found information for Sokac from Krunoslav Kićo Slabinac
# #######
# Succesfully found information for ŠOKAČKA GRANA from Krunoslav Kićo Slabinac
# #######
# Succesfully found information for Spomeni mi nekad ime from Krunoslav Kićo Slabinac
# #######
# Succesfully found information for Stani, suzo, stani from Krunoslav Kićo Slabinac
# #######
# Succesfully found information for Svatovac from Krunoslav Kićo Slabinac
# #######
# Succesfully found information for Svekrva from Krunoslav Kićo Slabinac
# #######
# Succesfully found information for Sviraj, svirce from Krunoslav Kićo Slabinac
# #######
# No info for the song svirci moji by Kićo on diskografija.com
# #######
# Succesfully found information for Tamburaši, samo svirajte from Krunoslav Kićo Slabinac
# #######
# Succesfully found information for Tekla voda Karasica from Krunoslav Kićo Slabinac
# #######
# No info for the song ti, koju znam by Kićo on diskografija.com
# #######
# Succesfully found information for Tiho, tiho, uspomeno from Krunoslav Kićo Slabinac
# #######
# No info for the song tri livade by Kićo on diskografija.com
# #######
# No info for the song te tri slatke rijeci by Kićo on diskografija.com
# #######
# Succesfully found information for Tuzna je Anuska from Krunoslav Kićo Slabinac
# #######
# Succesfully found information for U dugim nocima from Krunoslav Kićo Slabinac
# #######
# No info for the song varas me ti by Kićo on diskografija.com
# #######
# Succesfully found information for Vesela je Sokadija from Krunoslav Kićo Slabinac
# #######
# Succesfully found information for Violeta from Krunoslav Kićo Slabinac
# #######
# Succesfully found information for Vise neces biti moja from Krunoslav Kićo Slabinac
# #######
# No info for the song vukovar by Kićo on diskografija.com
# #######
# Succesfully found information for Zaboravi, moja ljubavi from Krunoslav Kićo Slabinac
# #######
# Succesfully found information for Zagreb i ja from Krunoslav Kićo Slabinac
# #######
# Succesfully found information for Zalit' cemo, duso, zalit' cemo from Krunoslav Kićo Slabinac
# #######
# Succesfully found information for Zbog jedne divne crne žene from Krunoslav Kićo Slabinac
# #######
# Succesfully found information for Zbog tvoje ljubavi from Krunoslav Kićo Slabinac
# #######
# Lyrics successfully written to file for : ako zora ne svane
# Couldn't find lyrics for song alaj volim u kolu igrati on cuspajz.com
# Couldn't find lyrics for song becarac  on cuspajz.com
# Couldn't find lyrics for song bila je tako lijepa, bila je tako mlada on cuspajz.com
# Couldn't find lyrics for song bila si djevojcica on cuspajz.com
# Couldn't find lyrics for song budi sretna slavonijo on cuspajz.com
# Couldn't find lyrics for song budi to sto jesi on cuspajz.com
# Couldn't find lyrics for song bura on cuspajz.com
# Couldn't find lyrics for song cija kola klepecu sokakom on cuspajz.com
# Couldn't find lyrics for song cija si on cuspajz.com
# Couldn't find lyrics for song crne oci dobro vide on cuspajz.com
# Lyrics successfully written to file for : cvijet ceznje
# Couldn't find lyrics for song da sam tvoje rijeci slusao, majko on cuspajz.com
# Couldn't find lyrics for song dan koji se pamti on cuspajz.com
# Couldn't find lyrics for song dobri stari radio on cuspajz.com
# Couldn't find lyrics for song dravski pecaros on cuspajz.com
# Lyrics successfully written to file for : ej tamburo
# Couldn't find lyrics for song ej,  cija frula ovim sorom svira on cuspajz.com
# Couldn't find lyrics for song ej, da mogu mladost vratiti on cuspajz.com
# Couldn't find lyrics for song golubice bijela on cuspajz.com
# Couldn't find lyrics for song gori lampa na srid vinkovaca on cuspajz.com
# Couldn't find lyrics for song ti, koju znam on cuspajz.com
# Couldn't find lyrics for song tiho, tiho, uspomeno on cuspajz.com
# Couldn't find lyrics for song tri livade on cuspajz.com
# Lyrics successfully written to file for : tri slatke rijeci
# Couldn't find lyrics for song tuzna je anuska on cuspajz.com
# Couldn't find lyrics for song u dugim nocima on cuspajz.com
# Couldn't find lyrics for song varas me ti on cuspajz.com
# Lyrics successfully written to file for : vesela je sokadija
# Couldn't find lyrics for song violeta on cuspajz.com
# Couldn't find lyrics for song vise neces biti moja on cuspajz.com
# Couldn't find lyrics for song vukovar on cuspajz.com
# Couldn't find lyrics for song zaboravi, moja ljubavi on cuspajz.com
# Couldn't find lyrics for song zagreb i ja on cuspajz.com
# Couldn't find lyrics for song zalit' cemo, duso, zalit' cemo on cuspajz.com
# Lyrics successfully written to file for : zbog jedne divne crne zene
# Couldn't find lyrics for song zbog tvoje ljubavi on cuspajz.com
# hej becari i bekrijegdje je vino da se pijegdje su cure gdje su snaseda natoce prazne caseiju ijuju nemoj mala da cujuda ne sazna tvoja mati da si meni rekla datida si meni rekla datitri dukata ispod vrata sorom sajke a svemirom lajkeja sam becar jedini u majkene zna becar za nikakve mukedok mu cure ravnaju jastukehej becari i bekrijeiz te ravne slavonijeo moj sore usoreninece becar da se zenina sporetu prigorilo ulje dok mi cura peglala kosuljecure ljubim zadirkujem snasesamo one koje se ne plase
# XXXXXX
# hej becari i bekrije iz te ravne slavonijeo moj sore usoreni nece becar da se zenihej becari i bekrije gdje je vino da se pijegdje su cure gdje su snase da natoce prazne casehej becari i bekrije iz te ravne slavonijegdje su cure gdje su snase tu ces naci tamburase
# 0.44
# XXXXXX
# XXXXXX
# sinoc bila misecinaa veceras tamaodvedi me diko kucine smim ici samastala nogom na botegupa sve veli  necu a kuma namigujeda se kola krecuaoj kceri je l to tajhulja i becarjeste majko to je tajal nije becarljubio sam curicuu sumi na panjukad ne daju po nocia ja cu po danu
# XXXXXX
# sinoc bila misecinaa veceras tamasinoc bila misecinaa veceras tamaodvedi me diko kucine smim ici samaodvedi me diko kucine smim ici samastala nogom na potegupa sve veli necustala nogom na potegupa sve veli necua na kuma namigujeda se kola krecua na kuma namigujeda se kola krecuja u stara kola necustara kola sve klepecuja u stara kola necustara kola sve klepecubecarova nova kola ocunova kola sve klopocupa sve cine cindildindilpa sve cine bluc blucljubio sam curicuu sumi na panjuljubio sam curicuu sumi na panjukad ne daju po nocia ja cu po danukad ne daju po nocia ja cu po danu
# 0.67
# XXXXXX
# XXXXXX
# tekla voda karasicado valpova od nasicaref 2xduna duna dunave tija vodo ladna otud ide mlad ivanvalpovacki kapetanref 2xej bora vam tri snasiceajte sa mnom u nasiceref 2xcastit cu vas sedam danaispec cu vam tri puranaref 2xbit ce pite pite svake vrstiza kojom se lizu prsiref 2xa kad bude sve gotovovratit cmo se u valpovoref 2x
# XXXXXX
# tekla voda karasica do valpova od nasicatekla voda karasica do valpova od nasicadunadunadunave tija vodo ladnadunadunadunave tija vodo ladnaod tud ide mlad ivane valpovacki kapetaneod tud ide mlad ivane valpovacki kapetaneoj bora vam tri snasice hajte sa mnom u nasiceoj bora vam tri snasice hajte sa mnom u nasicecastit cu vas sedam dana ispeci cu tri puranacastit cu vas sedam dana ispeci cu tri puranabit ce pite svake vrsti za kojom se lizu prstibit ce pite svake vrsti za kojom se lizu prstia kad bude sve gotovo vraticmo se u valpovoa kad bude sve gotovo vraticmo se u valpovo
# 0.61
# XXXXXX
# XXXXXX
# vesela sokadija kad tambura sorom svirarefveselo veselo aj veselo je sve seloveselo veselo veselo je sve selo gdje su case gdje su flasetu ces naci sokce naserefu gajdasa gajde jece a u sokca case zvecerefna tamburi zica pucea u sokca srce tuceref igra sokac i sokicadrma im se kabanicarefigra pajdas do pajdasaa do njega lipa snasaref
# XXXXXX
# vesela je sokadija kad tambura sorom svirau gajdasa gajde jece a u sokca case zveceigra sokac i sokica drma im se kabanicaigra pajdas do pajdasa a do njega lipa snasagdje su case gdje su flase tu ces naci sokce nasena tamburi zica puce a u sokca srce tuceveselo veselo haj veselo je sve selo
# 0.56
# XXXXXX
# XXXXXX
# <Release 1087448 'Vjenčanja Neće Biti / Moja Djevojka Marija'>
# <Release 3208698 'Jednom U Životu / Ne Shvaćam Te'>
# <Master 906316 'Plavuša / Taj Dan'>
# <Release 1382286 'Ne Pitaj S Kim Ni Zašto / Da Li Znaš'>
# <Release 3422834 'Više Nećeš Biti Moja'>
# <Master 1509982 'U Dugim Noćima / Angela, Čekaj Me'>
# <Master 863588 'Više Nećeš Biti Moja / Cvijet Čežnje'>
# <Release 1102572 'Tragovi / Živim Svoj Život'>
# <Release 2454061 'Čija Si'>
# <Master 432147 'Tri Slatke Riječi / Lamento'>
# <Master 1517608 'Pusti Da Te Vodim / Nemoj Biti Sretna'>
# <Master 1510016 'Tvoj Dječak Je Tužan'>
# <Master 322703 'Krunoslav Slabinac Kićo'>
# <Master 1788611 'Zbog Jedne Divne Crne Žene / Sviraj, Svirče'>
# <Release 1087461 'Život Bez Tebe / Dajem Ti Svoju Riječ'>
# <Master 1237128 'Plavi Pingvin / Poljubi Me Za Sretan Put'>
# <Master 709502 'Idi / Pokloni Mi Jedan Dan'>
# <Master 802780 'Bećarac'>
# <Master 1860063 'Balada O Ženi I Djetetu / Ostavljaš Me Samog'>
# <Release 1087473 'Da Sam Tvoje Riječi Slušao, Majko / Budi To Što Jesi'>
# <Release 2257793 'Tko Će Te Tako Zavoljeti / Znam Da Nisi Sretna'>
# <Release 3218702 'Kad Čujem Tambure / Lijepa Moja Slavonija'>
# <Release 5720149 'U Ime Slobode'>
# <Master 1256570 'Krunoslav Slabinac'>
# <Release 2073192 'Na Kraj Sela Čađava Mehana'>
# <Release 3018095 'Oko Moje Plavo I Garavo / Volim Diku, Dika Za Mnom Gine'>
# <Release 3220019 "Kol'kor Kapljic, Tol'ko Let / So Očka Mi D'jali">
# <Master 207155 'Hej Bećari'>
# <Release 1087456 'Ja Kakva Je Na Bendbaši Trava'>
# <Release 3220039 'Ostala Je Samo Želja / Digni Glavu Brate'>
# <Release 4118432 'Bagat'>
# <Release 4311505 'Dobri Stari Radio'>
# <Master 1991551 'Pružimo Si Ruke'>
# <Master 1443733 'Da Sam Tvoje Riječi Slušao Majko'>
# <Release 3211656 'Varaš Me Ti / Jedna Jedina Od Svih Žena'>
# <Release 3218676 'Glas Dječaka / Daj Obećanje'>
# <Release 3219994 'Karnevali, Karnevali'>
# <Release 3220126 'Rico, Moja Zlatna Rico'>
# <Release 6660754 'Putovi / Složna Srca, Složno Rade'>
# <Release 2076775 'Violeta / Duga Zimska Noć'>
# <Release 3223481 'Pusti Noćas Svoje Kose'>
# <Release 4138705 'Dan Koji Se Pamti / Samo Tako'>
# <Master 909045 'Najveći Uspjesi Četvorice Najvećih'>
# <Release 3211624 'Kad Su Tukle Stare Ure / Rusule Ti Nosim'>
# <Master 810310 'Seoska Sam Lola'>
# <Release 1534165 "Odrasti, Al' Ostani Mlada / Ja Pjesmom Teram Tugu">
# <Release 2073099 'Veronika / Sviraj Nam Rock'>
# <Release 4598290 'Zemljo Moja Draga / Vratit Ću Se Jednog Dana'>
# <Master 384776 'Rock And Roll'>
# <Release 5692456 'Moj Marjane Adio'>
# <Release 8164409 'Sretna Nova !'>
# <Master 404552 'Christmas With Kićo (Svim Na Zemlji Mir Veselje)'>
# <Master 650495 'Svatovac'>
# <Release 5522827 'Svatovac / Svi Se Momci Oženiše'>
# <Release 6864117 'Kad Čujem Tambure'>
# <Release 7718086 'Zagorja Sin / Teku Dani, Teku Cajti'>
# <Master 1443734 'Dok Sanjaš'>
# <Release 7288211 'Stani Suzo, Stani / Nina'>
# <Release 11565205 'Jugoton Express'>
# <Master 854290 'Rock And Roll 2'>
# <Master 397171 'Stani Suzo'>
# <Release 7288243 'Da Mi Je / Preko Mora I Planina'>
# <Release 10448315 'Jugoton Express'>
# <Master 1021621 "Da L' Se Sjećaš">
# <Master 560516 'Oj, Garava, Garava'>
# <Master 1105536 'Tiho, Tiho Uspomeno'>
# <Release 5901539 'Stop Za Bajke'>
# <Master 1347756 'Hrvatski Božić'>
# <Release 7639914 'Za Tebe...'>
# <Release 7440941 'Daj Mi Još Jemput Zapopevaj'>
# <Release 15460049 'Ako Zora Ne Svane'>
# <Master 1449610 'Sve Najbolje!'>
# <Master 1200047 'Ako Zora Ne Svane'>
# <Master 382384 "Rock' N' Roll ABC...">
# <Release 15353133 'Pusti Da Te Prebolim'>
# <Release 8416327 'Zlatna Kolekcija'>
# <Release 7648397 'The Platinum Collection'>
# <Release 7721549 'Dignite Čaše Svatovi'>
# <Release 3884986 'Vesela Je Šokadija'>
# <Release 5605855 'Najljepše Ljubavne Pjesme'>
# <Master 1132736 'Untitled'>
# <Release 9594336 '50 Originalnih Pjesama'>
# <Release 10504802 'Cvijet Čežnje - Kićo Dalmaciji'>
# <Release 4337439 'Tri Slatke Riječi'>
# <Release 4983627 'Jugoton Express'>
# <Release 12399909 'Изпълнения На Круно Слабинац'>
