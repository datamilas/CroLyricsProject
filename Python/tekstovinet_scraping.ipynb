# %%
import pandas as pd
import base64
import os

from requests import get
from bs4 import BeautifulSoup
from time import sleep
# Out:
# C:\Users\amilas\Miniconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %% [markdown]
# Already scraped
#
#
# #artist = "Severina"
# #diskografija_artist_name = 'Severina'
# #url = "https://tekstovi.net/2,212,0.html"
#
#
# artist = 'Mia Dimšić'
# diskografija_artist_name = 'Mia Dimšić'
# url = "https://tekstovi.net/2,4413,0.html"
#
#
# artist = 'Jelena Rozga'
# diskografija_artist_name = 'Jelena Rozga'
# url = "https://tekstovi.net/2,1156,0.html"

# %%
# Scraping tekstovi.net for song lyrics by artist (change url to change artist)

# Based on:
#    https://www.dataquest.io/blog/web-scraping-beautifulsoup/
#    https://github.com/aakashbansal/Songs-Lyrics-Web-Scraper/blob/master/Lyrics%20Scraper.ipynb



artist = 'Petar Grašo'
diskografija_artist_name = 'Petar Grašo'
url = "https://tekstovi.net/2,221,0.html"


## Create empty df:
column_names = ["Song_ID", "Artist", "Artist_diskografija", "Song_tekstovinet", "Views_tekstovinet", "Lyrics_tekstovinet", "Url_tekstovinet"]
df = pd.DataFrame(columns = column_names)


# generate random artist ID and make sure it doesnt have '_'
artist_ID = base64.b64encode(os.urandom(6)).decode('ascii')
while(artist_ID.find('_')>=0):
    artist_ID = base64.b64encode(os.urandom(6)).decode('ascii')
    
delay = 2

response = get(url)
# print(response.text[:500])
html_soup = BeautifulSoup(response.text, 'html.parser')
# print(type(html_soup))


# Get the list of songs
songs = html_soup.find_all('p', class_='artLyrList')
#songs = [s.findChild("a").text for s in songs_raw]

# %%
for index, song in enumerate(songs):
    song_name = song.findChild("a").text
    song_url = song.findChild("a")["href"]

    url = 'https://tekstovi.net/'+song_url

    response = get(url)
    html_soup = BeautifulSoup(response.text, 'html.parser')

    song_lyrics = html_soup.find_all('p', class_='lyric')
    lyrics = [l.text for l in song_lyrics]
    lyrics = " ".join(lyrics)
    song_ID = artist_ID + '_' + str(1) + '_' + str(index)
    views_text = html_soup.find('p', class_='lyric_impressions').text
    views_count = int("".join([c for c in views_text if c.isdigit()]))
    new_entry = pd.DataFrame([[song_ID, artist, diskografija_artist_name, song_name, views_count, lyrics, url]], columns=["Song_ID", "Artist", "Artist_diskografija", "Song_tekstovinet", "Views_tekstovinet", "Lyrics_tekstovinet", "Url_tekstovinet"])
    df = df.append(new_entry, ignore_index=True)

    print("Lyrics successfully written to file for : " + song_name)
                        
    sleep(delay)
# Out:
# Lyrics successfully written to file for : 92
# Lyrics successfully written to file for : Ako se rastanemo
# Lyrics successfully written to file for : Ako te pitaju
# Lyrics successfully written to file for : Baraba
# Lyrics successfully written to file for : Brod ljubavi
# Lyrics successfully written to file for : Da li iko navija za nas
# Lyrics successfully written to file for : Fritula (feat. Narodni)
# Lyrics successfully written to file for : Godine ljubavi
# Lyrics successfully written to file for : Gol, bos, sam
# Lyrics successfully written to file for : Idi
# Lyrics successfully written to file for : Je l' ti reka' 'ko
# Lyrics successfully written to file for : Jedina
# Lyrics successfully written to file for : Jos uvik slipo virujen
# Lyrics successfully written to file for : Kad ostarim
# Lyrics successfully written to file for : Kada krenu vlakovi
# Lyrics successfully written to file for : Ko nam brani
# Lyrics successfully written to file for : Lakse mi je s' njom
# Lyrics successfully written to file for : Ljubav jedne zene
# Lyrics successfully written to file for : Ljubav pozlati sve
# Lyrics successfully written to file for : Lomi me
# Lyrics successfully written to file for : Mjesec iznad oblaka
# Lyrics successfully written to file for : Moje zlato
# Lyrics successfully written to file for : More i ja, more i ti
# Lyrics successfully written to file for : Najteza ric
# Lyrics successfully written to file for : Ne boli me
# Lyrics successfully written to file for : Ne znan za se
# Lyrics successfully written to file for : Nece nas zauvik bit'
# Lyrics successfully written to file for : Nek' pisma ostane
# Lyrics successfully written to file for : Nevista
# Lyrics successfully written to file for : Ni mrvu srice
# Lyrics successfully written to file for : Nisan vise ja sa njom (duet Dino Radjo)
# Lyrics successfully written to file for : Odlucio sam slijediti Krista
# Lyrics successfully written to file for : Otkad nije mi tu
# Lyrics successfully written to file for : Prije bi umra
# Lyrics successfully written to file for : Prokleto sam
# Lyrics successfully written to file for : Prosjak ljubavi
# Lyrics successfully written to file for : Sad te se samo rijetko sjetim (feat. Arsen Dedic)
# Lyrics successfully written to file for : Sporke rici
# Lyrics successfully written to file for : Srce za vodica (feat. Hana Huljic)
# Lyrics successfully written to file for : Sta je tribalo mi to
# Lyrics successfully written to file for : Sta ti je svit
# Lyrics successfully written to file for : Sto je to od mene ostalo (duet Doris Dragovic)
# Lyrics successfully written to file for : Sve nas manje ima tu
# Lyrics successfully written to file for : Trebam nekoga
# Lyrics successfully written to file for : Utorak
# Lyrics successfully written to file for : Uvik isti
# Lyrics successfully written to file for : Vera od suvog zlata
# Lyrics successfully written to file for : Voli me
# Lyrics successfully written to file for : Volim i postojim
# Lyrics successfully written to file for : Vrbe

# %%
df.to_csv(f'data/{artist}_tekstovinet.csv', index=False)

# %%
df.sort_values(by=['Views_tekstovinet'])
# Out:
#           Song_ID       Artist Artist_diskografija  \
# 10  nkaHNg1X_1_10  Petar Grašo         Petar Grašo
# 26  nkaHNg1X_1_26  Petar Grašo         Petar Grašo
# 25  nkaHNg1X_1_25  Petar Grašo         Petar Grašo
# 38  nkaHNg1X_1_38  Petar Grašo         Petar Grašo
# 27  nkaHNg1X_1_27  Petar Grašo         Petar Grašo
# 8    nkaHNg1X_1_8  Petar Grašo         Petar Grašo
# 49  nkaHNg1X_1_49  Petar Grašo         Petar Grašo
# 3    nkaHNg1X_1_3  Petar Grašo         Petar Grašo
# 32  nkaHNg1X_1_32  Petar Grašo         Petar Grašo
# 31  nkaHNg1X_1_31  Petar Grašo         Petar Grašo
# 22  nkaHNg1X_1_22  Petar Grašo         Petar Grašo
# 34  nkaHNg1X_1_34  Petar Grašo         Petar Grašo
# 5    nkaHNg1X_1_5  Petar Grašo         Petar Grašo
# 24  nkaHNg1X_1_24  Petar Grašo         Petar Grašo
# 33  nkaHNg1X_1_33  Petar Grašo         Petar Grašo
# 23  nkaHNg1X_1_23  Petar Grašo         Petar Grašo
# 14  nkaHNg1X_1_14  Petar Grašo         Petar Grašo
# 47  nkaHNg1X_1_47  Petar Grašo         Petar Grašo
# 39  nkaHNg1X_1_39  Petar Grašo         Petar Grašo
# 29  nkaHNg1X_1_29  Petar Grašo         Petar Grašo
# 16                                Lakse mi je s' njom             32164
# 19                                            Lomi me             33110
# 40                                     Sta ti je svit             33719
# 12                             Jos uvik slipo virujen             33856
# 6                             Fritula (feat. Narodni)             40345
# 41     Sto je to od mene ostalo (duet Doris Dragovic)             47739
# 18                                 Ljubav pozlati sve             49201
# 21                                         Moje zlato             50706
# 17                                  Ljubav jedne zene             55329
# 0                                                  92             56927
# 46                                Vera od suvog zlata             57601
# 11                                             Jedina             61982
# 28                                            Nevista             65155
# 15                                       Ko nam brani             72683
# 43                                      Trebam nekoga             83067
# 36  Sad te se samo rijetko sjetim (feat. Arsen Dedic)             91930
# 48                                   Volim i postojim            138391
# 44                                             Utorak            151295
# 2                                       Ako te pitaju            185913
#
#                                    Lyrics_tekstovinet  \
# 10  Sve sta san o tebi zna\r\nsta san cuja, vidija...
# 26  Ref. 2x\r\nNece nas, nece nas\r\nzauvik bit'\r...
# 25  Ref. \r\nNe znan za se, ne znan za se\r\nsamo ...
# 38  Sto sam sve propustio\r\ndok te nisam vidio\r\...
# 27  Mozda je bilo rana \r\nal' rane zacijele \r\na...
# 8   Ljubav je lancun bili\r\nkoji se s tobon dili\...
# 49  Dvije su vrbe \r\npokraj rijeke tiho plakale\r...
# 3   Kazi mi s kim si \r\nnocas cekala zoru\r\nkome...
# 32  Ljubiti il' gubiti\r\nsasvim svejedno je sad\r...
# 31  Ljubavlju vjecnom ljubim te\r\nzato ti sacuvah...
# 22  Pobit' cu nocas u note i stih \r\njer jos te i...
# 34  Svega tvoga, evo se, odricem\r\nodavno drugoj ...
# 5   Kada zivot zbroji sve \r\nporazi i pobjede\r\n...
# 24  Tvoje srce bilo je\r\nprvi susid do moga\r\nbu...
# 33  Evo me opet \r\ndi mislin na nas \r\nnevin ka'...
# 23  Ponovo si bez da san prista \r\nkroz moj zivot...
# 14  Lako tebi, ti se uvijek\r\nNekom vratis\r\nI b...
# 47  Ko pamti sve sve noci te\r\nmamurluke i sjaj i...
# 39  Kad ugrize nas zub \r\nod vrimena i pomuti sja...
# 29  Zlatna ti zora bilo lice ljubi\r\nka' rosa cvi...
# 45  Nisan uvik bija\r\ndobar za se\r\nlipe bukune\...
# 35  Ja san disperan\r\nni jednom mistu na tom svit...
# 30  Nisan vise ja sa njon\r\nne smin naglas reci t...
# 20  U tajnom gradu srca mog\r\nskrivenom u predgra...
# 1   Ne govorim s tobom\r\ni nista nije kao prije\r...
# 9   Vrijeme leti, vrijeme mijenja sve\r\ntesko mi ...
# 7   Usla je tiho ka' brod\r\nu pismu moju i odnila...
# 42  Ako je volit bija grih\r\nja svoju kaznu sam p...
# 4   Iznad tihog oceana\r\nbura, nevera, orkana\r\n...
# 13  Ne vjeruj \r\nKad kazu da sam lud \r\nDa me zn...
# 37  Sidi da ti kazen sve\r\nza sve puste godine\r\...
# 16  Lakse mi je s njom\r\nnego sa tobom \r\ndala m...
# 19  Godine su pomele \r\nvragove i andjele\r\nlipo...
# 40  Sve lipe sate\r\nprovela mi dusa s tvojon\r\nz...
# 12  Jos uvik slipo virujen\r\nda 'vaka jubav pukni...
# 6   Kasna svirka, rani let\r\niden doma, dan je sv...
# 41  Da je srce list duhana\r\npepeo i tama\r\nda s...
# 18  Tvrda je kora od kruha\r\nsto tjera nas na dal...
# 21  Prije tebe zivot moj\r\npucanj bija je u prazn...
# 17  Nebo moje ljubavi\r\nprekrila je siva boja \r\...
# 0   Otkad nema te tu \r\nsve duzi je dan\r\nsve te...
# 46  Idem doma jer kasni je sat \r\nona me ceka sva...
# 11  Jedina, jos te ima posvuda \r\nsvaki dan je os...
# 28  Da si, da si moja nevista\r\nne bi prazna bila...
# 15  Nekad cini mi se\r\nda je propalo sve \r\nnist...
# 43  Vracam ti se opet, Boze moj\r\nda pokazes mi p...
# 36  Uvijek tako pocinje, polja cvatu\r\ncuvaj tamn...
# 48  Hej, ljubavi\r\nzagrli me zagrli\r\nnek' nitko...
# 44  Pred tebe razlit' cu svoju bol\r\nk'o crno vin...
# 2   Jos su do lani\r\nmoje noci, moji dani \r\nbil...
#
#                           Url_tekstovinet
# 10  https://tekstovi.net/2,221,64675.html
# 26  https://tekstovi.net/2,221,61767.html
# 25  https://tekstovi.net/2,221,52738.html
# 38  https://tekstovi.net/2,221,51661.html
# 27   https://tekstovi.net/2,221,5711.html
# 8    https://tekstovi.net/2,221,5672.html
# 49   https://tekstovi.net/2,221,5775.html
# 3    https://tekstovi.net/2,221,5622.html
# 32   https://tekstovi.net/2,221,5710.html
# 31  https://tekstovi.net/2,221,19643.html
# 22   https://tekstovi.net/2,221,2699.html
# 34  https://tekstovi.net/2,221,20859.html
# 5    https://tekstovi.net/2,221,5627.html
# 24   https://tekstovi.net/2,221,5705.html
# 33   https://tekstovi.net/2,221,5712.html
# 23   https://tekstovi.net/2,221,5723.html
# 14   https://tekstovi.net/2,221,2491.html
# 47  https://tekstovi.net/2,221,58073.html
# 39   https://tekstovi.net/2,221,5774.html
# 29   https://tekstovi.net/2,221,5707.html
# 45  https://tekstovi.net/2,221,45358.html
# 35   https://tekstovi.net/2,221,8878.html
# 30   https://tekstovi.net/2,221,5709.html
# 20   https://tekstovi.net/2,221,5722.html
# 1    https://tekstovi.net/2,221,5621.html
# 9    https://tekstovi.net/2,221,5673.html
# 7    https://tekstovi.net/2,221,5671.html
# 42   https://tekstovi.net/2,221,5776.html
# 4    https://tekstovi.net/2,221,5623.html
# 13   https://tekstovi.net/2,221,2698.html
# 37   https://tekstovi.net/2,221,5773.html
# 16   https://tekstovi.net/2,221,5679.html
# 19   https://tekstovi.net/2,221,5675.html
# 40  https://tekstovi.net/2,221,14568.html
# 12   https://tekstovi.net/2,221,5676.html
# 6   https://tekstovi.net/2,221,57436.html
# 41   https://tekstovi.net/2,221,5777.html
# 18   https://tekstovi.net/2,221,5678.html
# 21  https://tekstovi.net/2,221,49288.html
# 17   https://tekstovi.net/2,221,5680.html
# 0    https://tekstovi.net/2,221,5620.html
# 46   https://tekstovi.net/2,221,2489.html
# 11   https://tekstovi.net/2,221,5674.html
# 28   https://tekstovi.net/2,221,5708.html
# 15   https://tekstovi.net/2,221,5677.html
# 43   https://tekstovi.net/2,221,9140.html
# 36   https://tekstovi.net/2,221,2695.html
# 48   https://tekstovi.net/2,221,4519.html
# 44   https://tekstovi.net/2,221,2694.html
# 2   https://tekstovi.net/2,221,55130.html
